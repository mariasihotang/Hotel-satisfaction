# %% [markdown]
# # Import CSV

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("Dataset6_Hotel_Satisfaction.csv")
df.head()
# Out:
#        id  Gender  Age purpose_of_travel   Type of Travel Type Of Booking  \
# 0   70172    Male   13          aviation  Personal Travel     Not defined
# 1    5047    Male   25           tourism     Group Travel  Group bookings
# 2  110028  Female   26           tourism     Group Travel  Group bookings
# 3   24026  Female   25           tourism     Group Travel  Group bookings
# 4  119299    Male   61          aviation     Group Travel  Group bookings
#
#    Hotel wifi service  Departure/Arrival  convenience  Ease of Online booking  \
# 0                   3                               4                       3
# 1                   3                               2                       3
# 2                   2                               2                       2
# 3                   2                               5                       5
# 4                   3                               3                       3
#
# ...

# %% [markdown]
# # Data Description

# %% [markdown]
# ## About Dataset:
# - Age - 7 to 85
# - purposeoftravel - aviation, academic, personal, business, tourism.
# - Type of Travel - Group travel, Personal Travel.
# - Type Of Booking - Group bookings, Individual/Couple.
# - Hotel wifi service - Ratings out of 5.
# - Departure/Arrival convenience - Ratings out of 5.
# - Ease of Online booking - Ratings out of 5.
# - Hotel location - Ratings out of 5.
# - Food and drink - Ratings out of 5.
# - Stay comfort - Ratings out of 5.
# - Common Room entertainment - Ratings out of 5.
# - Checkin/Checkout service - Ratings out of 5.
# - Other service - Ratings out of 5.
# - Cleanliness - Ratings out of 5.
# - satisfaction - satisfied, neutral or dissatisfied.

# %% [markdown]
# # Data Understanding

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              103904 non-null  int64
#  1   Gender                          103904 non-null  object
#  2   Age                             103904 non-null  int64
#  3   purpose_of_travel               103904 non-null  object
#  4   Type of Travel                  103904 non-null  object
#  5   Type Of Booking                 103904 non-null  object
#  6   Hotel wifi service              103904 non-null  int64
#  7   Departure/Arrival  convenience  103904 non-null  int64
#  8   Ease of Online booking          103904 non-null  int64
#  9   Hotel location                  103904 non-null  int64
#  10  Food and drink                  103904 non-null  int64
#  11  Stay comfort                    103904 non-null  int64
# ...

# %%
df.describe()
# Out:
#                   id            Age  Hotel wifi service  \
# count  103904.000000  103904.000000       103904.000000
# mean    64924.210502      39.379706            2.729683
# std     37463.812252      15.114964            1.327829
# min         1.000000       7.000000            0.000000
# 25%     32533.750000      27.000000            2.000000
# 50%     64856.500000      40.000000            3.000000
# 75%     97368.250000      51.000000            4.000000
# max    129880.000000      85.000000            5.000000
#
#        Departure/Arrival  convenience  Ease of Online booking  Hotel location  \
# count                   103904.000000           103904.000000   103904.000000
# mean                         3.060296                2.756901        2.976883
# std                          1.525075                1.398929        1.277621
# min                          0.000000                0.000000        0.000000
# ...

# %%
df.describe(include='object')
# Out:
#         Gender purpose_of_travel Type of Travel Type Of Booking  \
# count   103904            103904         103904          103904
# unique       2                 5              2               3
# top     Female           tourism   Group Travel  Group bookings
# freq     52727             32053          71655           49665
#
#                    satisfaction
# count                    103904
# unique                        2
# top     neutral or dissatisfied
# freq                      58879

# %%
df.isna().sum()
# Out:
# id                                0
# Gender                            0
# Age                               0
# purpose_of_travel                 0
# Type of Travel                    0
# Type Of Booking                   0
# Hotel wifi service                0
# Departure/Arrival  convenience    0
# Ease of Online booking            0
# Hotel location                    0
# Food and drink                    0
# Stay comfort                      0
# Common Room entertainment         0
# Checkin/Checkout service          0
# Other service                     0
# Cleanliness                       0
# satisfaction                      0
# dtype: int64

# %%
df[df.duplicated(keep='first')]
# Out:
# Empty DataFrame
# Columns: [id, Gender, Age, purpose_of_travel, Type of Travel, Type Of Booking, Hotel wifi service, Departure/Arrival  convenience, Ease of Online booking, Hotel location, Food and drink, Stay comfort, Common Room entertainment, Checkin/Checkout service, Other service, Cleanliness, satisfaction]
# Index: []

# %%
df.drop(columns='id', inplace=True)

# %%
print(df['Type Of Booking'].value_counts())
print("-"*30)
print(df['Type Of Booking'].value_counts(normalize=True))
# Out:
# Group bookings       49665
# Individual/Couple    46745
# Not defined           7494
# Name: Type Of Booking, dtype: int64
# ------------------------------
# Group bookings       0.477989
# Individual/Couple    0.449886
# Not defined          0.072124
# Name: Type Of Booking, dtype: float64

# %%
df.drop(df[df['Type Of Booking'] == 'Not defined'].index, inplace = True)

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'purpose_of_travel', 'Type of Travel',
#        'Type Of Booking', 'Hotel wifi service',
#        'Departure/Arrival  convenience', 'Ease of Online booking',
#        'Hotel location', 'Food and drink', 'Stay comfort',
#        'Common Room entertainment', 'Checkin/Checkout service',
#        'Other service', 'Cleanliness', 'satisfaction'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96410 entries, 1 to 103903
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          96410 non-null  object
#  1   Age                             96410 non-null  int64
#  2   purpose_of_travel               96410 non-null  object
#  3   Type of Travel                  96410 non-null  object
#  4   Type Of Booking                 96410 non-null  object
#  5   Hotel wifi service              96410 non-null  int64
#  6   Departure/Arrival  convenience  96410 non-null  int64
#  7   Ease of Online booking          96410 non-null  int64
#  8   Hotel location                  96410 non-null  int64
#  9   Food and drink                  96410 non-null  int64
#  10  Stay comfort                    96410 non-null  int64
#  11  Common Room entertainment       96410 non-null  int64
# ...

# %% [markdown]
# # EDA

# %%
fig, axarr = plt.subplots(2,2, figsize=(20,12))
sns.countplot(x='Gender', hue='satisfaction', data=df, ax=axarr[0][0])
sns.countplot(x='purpose_of_travel', hue='satisfaction', data=df, ax=axarr[0][1])
sns.countplot(x='Type of Travel', hue='satisfaction', data=df, ax=axarr[1][0])
sns.countplot(x='Type Of Booking', hue='satisfaction', data=df, ax=axarr[1][1])
# Out:
# <AxesSubplot:xlabel='Type Of Booking', ylabel='count'>

# %% [markdown]
# ### Based on the visualization above:
# 1. In the Gender column, the number for the satisfied and neutral/dissatisfied is almost the same
# 2. In the purpose of travel, there are 5 types which are tourism, aviation, business, academic, personal. Tourism is the highest number for both satisfied and neutral/dissatisfied.
# 3. In the type of travel, the highest number for satisfied and neutral/dissatisfied is in group travel
# 4. In the type of booking, the highest number for satisfied is in group bookings and for the neutral/dissatisfied is in individual/couple

# %%
fig, axarr = plt.subplots(3,2, figsize=(20,12))
sns.countplot(x='Hotel wifi service', hue='satisfaction', data=df, ax=axarr[0][0])
sns.countplot(x='Departure/Arrival  convenience', data=df, hue='satisfaction', ax=axarr[0][1])
sns.countplot(x='Ease of Online booking', data=df, hue='satisfaction', ax=axarr[1][0])
sns.countplot(x='Hotel location', data=df, hue='satisfaction', ax=axarr[1][1])
sns.countplot(x='Food and drink', hue='satisfaction', data=df, ax=axarr[2][0])
sns.countplot(x='Stay comfort', hue='satisfaction', data=df, ax=axarr[2][1])
# Out:
# <AxesSubplot:xlabel='Stay comfort', ylabel='count'>

# %%
fig, axarr = plt.subplots(2,2, figsize=(20,12))
sns.countplot(x='Common Room entertainment', data=df, hue='satisfaction', ax=axarr[0][0])
sns.countplot(x='Checkin/Checkout service', data=df, hue='satisfaction', ax=axarr[0][1])
sns.countplot(x='Other service', hue='satisfaction', data=df, ax=axarr[1][0])
sns.countplot(x='Cleanliness', hue='satisfaction', data=df, ax=axarr[1][1])
# Out:
# <AxesSubplot:xlabel='Cleanliness', ylabel='count'>

# %% [markdown]
# ### Base on the visualization above:
# If we look closely by assuming that 0-3 is neutral/dissatisfied and 4-5 is satisfied, we can conclude that the highest neutral/dissatisfied is in:
# 1. Hotel wifi service
# 2. Hotel location
# 3. Ease of online booking

# %%
def age_group(age):
  if age < 40:
    return "Young"
  elif age > 60:
    return "Old"
  else:
    return "Middle"
  
df['age_group'] = df['Age'].apply(lambda age: age_group(age))

# %%
sns.countplot(x='age_group', data=df, hue='satisfaction')
# Out:
# <AxesSubplot:xlabel='age_group', ylabel='count'>

# %%
df['age_group'].value_counts()
# Out:
# Young     47307
# Middle    42004
# Old        7099
# Name: age_group, dtype: int64

# %%
fig, axarr = plt.subplots(figsize=(3,3))
sns.countplot(data=df, x='satisfaction')
# Out:
# <AxesSubplot:xlabel='satisfaction', ylabel='count'>

# %%
data = df.groupby("satisfaction")['satisfaction'].count()
pie, ax = plt.subplots(figsize=[5,5])
data.plot.pie(autopct="%.f%%")
# Out:
# <AxesSubplot:ylabel='satisfaction'>

# %%
cm = df.corr()
plt.figure(figsize=(10,5))
sns.heatmap(cm, annot=True, cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Feature engineering

# %%
df.head()
# Out:
#    Gender  Age purpose_of_travel   Type of Travel    Type Of Booking  \
# 1    Male   25           tourism     Group Travel     Group bookings
# 2  Female   26           tourism     Group Travel     Group bookings
# 3  Female   25           tourism     Group Travel     Group bookings
# 4    Male   61          aviation     Group Travel     Group bookings
# 5  Female   26          business  Personal Travel  Individual/Couple
#
#    Hotel wifi service  Departure/Arrival  convenience  Ease of Online booking  \
# 1                   3                               2                       3
# 2                   2                               2                       2
# 3                   2                               5                       5
# 4                   3                               3                       3
# 5                   3                               4                       2
#
#    Hotel location  Food and drink  Stay comfort  Common Room entertainment  \
# ...

# %%
df.replace({'satisfaction':{'satisfied':0, 'neutral or dissatisfied':1}}, inplace=True)
df.head()
# Out:
#    Gender  Age purpose_of_travel   Type of Travel    Type Of Booking  \
# 1    Male   25           tourism     Group Travel     Group bookings
# 2  Female   26           tourism     Group Travel     Group bookings
# 3  Female   25           tourism     Group Travel     Group bookings
# 4    Male   61          aviation     Group Travel     Group bookings
# 5  Female   26          business  Personal Travel  Individual/Couple
#
#    Hotel wifi service  Departure/Arrival  convenience  Ease of Online booking  \
# 1                   3                               2                       3
# 2                   2                               2                       2
# 3                   2                               5                       5
# 4                   3                               3                       3
# 5                   3                               4                       2
#
#    Hotel location  Food and drink  Stay comfort  Common Room entertainment  \
# ...

# %%
df1 = pd.get_dummies(df)
df1.head()
# Out:
#    Age  Hotel wifi service  Departure/Arrival  convenience  \
# 1   25                   3                               2
# 2   26                   2                               2
# 3   25                   2                               5
# 4   61                   3                               3
# 5   26                   3                               4
#
#    Ease of Online booking  Hotel location  Food and drink  Stay comfort  \
# 1                       3               3               1             1
# 2                       2               2               5             5
# 3                       5               5               2             2
# 4                       3               3               4             5
# 5                       2               1               1             1
#
#    Common Room entertainment  Checkin/Checkout service  Other service  ...  \
# 1                          1                         1              4  ...
# ...

# %%
df1.columns
# Out:
# Index(['Age', 'Hotel wifi service', 'Departure/Arrival  convenience',
#        'Ease of Online booking', 'Hotel location', 'Food and drink',
#        'Stay comfort', 'Common Room entertainment', 'Checkin/Checkout service',
#        'Other service', 'Cleanliness', 'satisfaction', 'Gender_Female',
#        'Gender_Male', 'purpose_of_travel_academic',
#        'purpose_of_travel_aviation', 'purpose_of_travel_business',
#        'purpose_of_travel_personal', 'purpose_of_travel_tourism',
#        'Type of Travel_Group Travel', 'Type of Travel_Personal Travel',
#        'Type Of Booking_Group bookings', 'Type Of Booking_Individual/Couple'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
x = df1.drop('satisfaction', axis=1).copy()
y = df1['satisfaction'].copy()

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((77128, 22), (19282, 22), (77128,), (19282,))

# %% [markdown]
# # Modeling

# %%
# fit models
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

# scoring functions
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %% [markdown]
# ## KNN

# %%
knn = KNeighborsClassifier()
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_knn = knn.predict(x_test)
print(classification_report(y_test, y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.88      0.89      8602
#            1       0.90      0.92      0.91     10680
#
#     accuracy                           0.90     19282
#    macro avg       0.90      0.90      0.90     19282
# weighted avg       0.90      0.90      0.90     19282

# %% [markdown]
# ## Gradient boosting

# %%
gbc = GradientBoostingClassifier()
gbc.fit(x_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred_gbc = gbc.predict(x_test)
print(classification_report(y_test, y_pred_gbc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.92      0.92      8602
#            1       0.94      0.93      0.93     10680
#
#     accuracy                           0.93     19282
#    macro avg       0.93      0.93      0.93     19282
# weighted avg       0.93      0.93      0.93     19282

# %% [markdown]
# ## Random forest

# %%
rf = RandomForestClassifier()
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_rf = rf.predict(x_test)
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94      8602
#            1       0.95      0.96      0.95     10680
#
#     accuracy                           0.95     19282
#    macro avg       0.95      0.95      0.95     19282
# weighted avg       0.95      0.95      0.95     19282

# %% [markdown]
# # Feature Importance

# %%
fi = rf.feature_importances_
col = x_train.columns
plt.barh(col,fi)
# Out:
# <BarContainer object of 22 artists>

# %% [markdown]
# # Conclusions
# Based on the pattern, we can conclude:
# 1. There are 3 important things that affect on the hotel satisfaction which are: Hotel wifi service, Hotel location, Ease of online booking
# 2. From the pattern of neutral/dissatisfied, we can find that customers that gender "Female", purpose of travel "Tourism", type of travel "Group Travel", type of booking "Individual/Couple", and age between 40 until 60 which is "Middle"
#
# To improve the hotel satisfaction level, we need to focus on those 3 aspects which are: Hotel wifi service, hotel location, ease of online booking. We can also give promos for tourism, group travel, individual/couple category.
#
# For the modeling, random forest is the best model for the data that can predict the customer will be satisfied or neutral/dissatisfied. The accuracy for random forest model is 95%.
